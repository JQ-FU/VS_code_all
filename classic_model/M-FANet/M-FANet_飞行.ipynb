# %%
import random
import torch
from sklearn.model_selection import KFold
import math
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

# %%
import torch
import torch.nn as nn
from torchsummary import summary

# 定义 SEBlock 类
class SEBlock(nn.Module):
    def __init__(self, pool_type, in_channels, reduction):
        super(SEBlock, self).__init__()
        self.global_pool = nn.AdaptiveAvgPool2d(1) if pool_type == "avg" else nn.AdaptiveMaxPool2d(1)
        self.fc1 = nn.Conv2d(in_channels, in_channels // reduction, kernel_size=1)
        self.fc2 = nn.Conv2d(in_channels // reduction, in_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        scale = self.global_pool(x)
        scale = self.fc1(scale)
        scale = nn.ReLU()(scale)
        scale = self.fc2(scale)
        scale = self.sigmoid(scale)
        return x * scale

# 定义 M_FANet 类
class M_FANet(nn.Module):
    def __init__(self, Ks, Ft, Kt, D, Nc):
        super(M_FANet, self).__init__()

        self.pointwiseconv2d = nn.Conv2d(in_channels=9, out_channels=1, kernel_size=1, stride=1, padding=0, bias=False)
        
        # 确保 padding 为整数
        padding = Ks // 2  # 使用整数进行padding计算
        self.conv2d1 = nn.Conv2d(in_channels=1, out_channels=1, kernel_size=(Ks, 1),  padding='same')
        
        self.TSconv = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=Ft, kernel_size=(1, Kt), padding=(0, Kt // 2)),  # padding 需要是一个元组
            nn.BatchNorm2d(Ft),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Conv2d(in_channels=Ft, out_channels=D * Ft, kernel_size=(30, 1), groups=Ft),
            nn.AvgPool2d(kernel_size=(1, 4))
        )
        
        self.SEBlock = SEBlock("avg", D * Ft, 16)
        
        self.TConv = nn.Sequential(
            nn.Conv2d(in_channels=D * Ft, out_channels=D * Ft, kernel_size=(1, 25), groups=D * Ft, padding=(0, 12)),
            nn.AvgPool2d(kernel_size=(1, 8))
        )
        
        self.classifier = nn.Conv2d(D * Ft, Nc, (1, 6))

    def forward(self, x):
        x = self.pointwiseconv2d(x)
        x = self.conv2d1(x)
        x = self.TSconv(x)
        x = self.SEBlock(x)
        x = self.TConv(x)
        x = self.classifier(x)
        return x

# %%
#导入数据
#rest1
datapath1=r'D:\JQ_YJS\分频段\filtered_rest1.npy' 
data1=np.load(datapath1)
print(data1.shape)


#rest2
datapath2=r'D:\JQ_YJS\分频段\filtered_rest2.npy' 
data2=np.load(datapath2)
print(data2.shape)

data_all=np.concatenate((data1,data2),axis=0)
#标签制作
label_all = torch.cat([torch.zeros(6344), torch.ones(6589)]).long()  # 标签：前10505个为0，后10505个为1
print(label_all.shape)
print(data_all.shape)
# Out:
# (6344, 9, 30, 200)
# (6589, 9, 30, 200)
# torch.Size([12933])
# (12933, 9, 30, 200)

# %%
# 创建十折交叉验证
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# 保存结果的列表
historys = []
test_pred = []
test_real = []
accuracy, precision, recall, f1score = [], [], [], []
batchsz = 16
num_epochs = 100

# 进行十折交叉验证
for fold, (train_ind, test_ind) in enumerate(kfold.split(data_all, label_all)):
    print('fold号:', fold + 1)

    # 每一折验证前都要打乱训练集样本顺序
    n = len(train_ind)
    A = np.linspace(0, n - 1, n, dtype=int)
    random.shuffle(A)

    # 构建训练集、验证集、测试集
    epoch_train = data_all[train_ind[A[:int(0.8 * n)]]]
    epoch_val = data_all[train_ind[A[int(0.8 * n):]]]
    epoch_test = data_all[test_ind]
    label_train = label_all[train_ind[A[:int(0.8 * n)]]]
    label_val = label_all[train_ind[A[int(0.8 * n):]]]
    label_test = label_all[test_ind]

    # 转换为Tensor并创建DataLoader
    train_dataset = TensorDataset(torch.tensor(epoch_train, dtype=torch.float32), torch.tensor(label_train, dtype=torch.long))
    val_dataset = TensorDataset(torch.tensor(epoch_val, dtype=torch.float32), torch.tensor(label_val, dtype=torch.long))
    
    train_loader = DataLoader(train_dataset, batch_size=batchsz, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batchsz, shuffle=False)

    # 选择、创建模型
    model = M_FANet(Ks=4, Ft=16, Kt=3, D=2, Nc=1)
    #print(model)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    # 配置模型训练
    criterion = nn.BCEWithLogitsLoss()  # 使用交叉熵损失
    
    #optimizer = optim.SGD(model.parameters(), lr=1e-4)
    optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)

    # 开始训练模型
    print('开始训练!!')
    history = {'train_loss': [], 'val_loss': []}

    for epoch in range(num_epochs):  # 训练100个epoch
        model.train()
        running_loss = 0.0

        # 训练阶段
        for inputs, targets in train_loader:
            #print(f"训练批次输入数据形状: {inputs.shape}")
            inputs = inputs.to(device)
            
            targets = targets.to(device)
            optimizer.zero_grad()
            
            outputs = model(inputs)
            targets = targets.view(-1).float() 
            #targets=targets.view(-1,1).float()
            loss = criterion(outputs.view(-1), targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)
        history['train_loss'].append(avg_train_loss)

        #print('Epoch:{}/{}'.format(epoch+1,num_epochs))
        
        # 计算训练集的指标
        with torch.no_grad():
            train_pred = model(torch.tensor(epoch_train, dtype=torch.float32).to(device))
            train_pred = (torch.sigmoid(train_pred) > 0.5).cpu().numpy().astype(int)
            print("label_train shape:", label_train.shape)
            print("train_pred shape:", train_pred.shape)
            # 将 train_pred 进行维度压缩
            train_pred = train_pred.squeeze()


            acc_train = accuracy_score(label_train, train_pred)
            pre_train = precision_score(label_train, train_pred, average='macro')
            rec_train = recall_score(label_train, train_pred, average='macro')
            f1_train = f1_score(label_train, train_pred, average='macro')

        # 输出训练集指标
       
        # 验证阶段
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                

                inputs = inputs.to(device)
            
                targets = targets.to(device)
                outputs = model(inputs)
                #targets=targets.view(-1,1).float()
                targets = targets.view(-1).float()
                loss = criterion(outputs.view(-1), targets)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        
        history['val_loss'].append(avg_val_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, VAL Loss: {avg_val_loss:.4f}')
        #print(f'Epoch [{epoch+1}/{num_epochs}], VAL Loss: {avg_val_loss:.4f}')
        print(f"$$训练集准确率 accuracy: {acc_train}",f"$$训练集精确率 precision: {pre_train}",f"$$训练集召回率 recall: {rec_train}",f"$$训练集 F1 评分 f1_score: {f1_train}")
        


        # 保存训练记录
        historys.append(history)
        

        # 计算、保存测试结果
        model.eval()
        with torch.no_grad():
            pred_test = model(torch.tensor(epoch_test, dtype=torch.float32).to(device))
            
            pred_test = (torch.sigmoid(pred_test) > 0.5).cpu().numpy().astype(int)


        # 保存预测结果和真实结果
        test_pred.append(pred_test)
        test_real.append(label_test)
        # 将 train_pred 进行维度压缩
        pred_test = pred_test.squeeze()

        # 计算准确率，精确率，召回率，F1评分
        acc = accuracy_score(label_test, pred_test)
        pre = precision_score(label_test, pred_test, average='macro')
        rec = recall_score(label_test, pred_test, average='macro')
        f1 = f1_score(label_test, pred_test, average='macro')
        
        accuracy.append(acc)
        precision.append(pre)
        recall.append(rec)
        f1score.append(f1)
        
        print(f"@@测试集准确率 accuracy: {acc}",f"@@测试集精确率 precision: {pre}",f"@@测试集召回率 recall: {rec}",f"@@测试集 F1 评分 f1_score: {f1}")
        

# 将每一折 history 中误差结果保存（训练集和测试集，用于反映训练过程）    
loss_train = []
loss_val = []
for history_s in historys:
    loss_val.append(history_s['val_loss'])
    loss_train.append(history_s['train_loss'])
# Out:
# fold号: 1
# C:\Users\FJQ\AppData\Local\Temp\ipykernel_25560\1135995151.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_dataset = TensorDataset(torch.tensor(epoch_train, dtype=torch.float32), torch.tensor(label_train, dtype=torch.long))
# C:\Users\FJQ\AppData\Local\Temp\ipykernel_25560\1135995151.py:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   val_dataset = TensorDataset(torch.tensor(epoch_val, dtype=torch.float32), torch.tensor(label_val, dtype=torch.long))
# 开始训练!!
# d:\anaconda\envs\DL\lib\site-packages\torch\nn\modules\conv.py:454: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\Convolution.cpp:1032.)
#   return F.conv2d(input, weight, bias, self.stride,
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [1/100], Train Loss: 0.6595, VAL Loss: 0.6182
# $$训练集准确率 accuracy: 0.7763935130490818 $$训练集精确率 precision: 0.7990873378712452 $$训练集召回率 recall: 0.7731594576725744 $$训练集 F1 评分 f1_score: 0.7705894674357904
# @@测试集准确率 accuracy: 0.7217928902627512 @@测试集精确率 precision: 0.7708636584182436 @@测试集召回率 recall: 0.7240682339449541 @@测试集 F1 评分 f1_score: 0.7099001614156752
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [2/100], Train Loss: 0.5478, VAL Loss: 0.5394
# $$训练集准确率 accuracy: 0.7753195145526797 $$训练集精确率 precision: 0.7931689250610968 $$训练集召回率 recall: 0.7780730316367512 $$训练集 F1 评分 f1_score: 0.7729307551723485
# @@测试集准确率 accuracy: 0.7774343122102009 @@测试集精确率 precision: 0.7784048355193671 @@测试集召回率 recall: 0.777090500764526 @@测试集 F1 评分 f1_score: 0.7770743157396042
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [3/100], Train Loss: 0.4866, VAL Loss: 0.5101
# $$训练集准确率 accuracy: 0.7827301041778542 $$训练集精确率 precision: 0.8058736636987881 $$训练集召回率 recall: 0.7858193561562931 $$训练集 F1 评分 f1_score: 0.7797111758164319
# @@测试集准确率 accuracy: 0.7990726429675425 @@测试集精确率 precision: 0.8065625307004618 @@测试集召回率 recall: 0.7982129204892967 @@测试集 F1 评分 f1_score: 0.7975009630200308
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [4/100], Train Loss: 0.4622, VAL Loss: 0.5081
# $$训练集准确率 accuracy: 0.80098807861669 $$训练集精确率 precision: 0.8184076495037327 $$训练集召回率 recall: 0.8036247518619644 $$训练集 F1 评分 f1_score: 0.7991027177720569
# @@测试集准确率 accuracy: 0.785935085007728 @@测试集精确率 precision: 0.8142952227760037 @@测试集召回率 recall: 0.7842961582568808 @@测试集 F1 评分 f1_score: 0.7803132778086611
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [5/100], Train Loss: 0.4522, VAL Loss: 0.4702
# $$训练集准确率 accuracy: 0.8162388572655999 $$训练集精确率 precision: 0.8278453331462261 $$训练集召回率 recall: 0.8183672971957137 $$训练集 F1 评分 f1_score: 0.8152182028417347
# @@测试集准确率 accuracy: 0.8145285935085008 @@测试集精确率 precision: 0.8146036527060623 @@测试集召回率 recall: 0.8144232607033639 @@测试集 F1 评分 f1_score: 0.8144647700524537
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [6/100], Train Loss: 0.4370, VAL Loss: 0.4580
# $$训练集准确率 accuracy: 0.8284824401245838 $$训练集精确率 precision: 0.8363331149827435 $$训练集召回率 recall: 0.8302190649965853 $$训练集 F1 评分 f1_score: 0.827924898726559
# @@测试集准确率 accuracy: 0.8245749613601236 @@测试集精确率 precision: 0.8294253717018221 @@测试集召回率 recall: 0.8239105504587156 @@测试集 F1 评分 f1_score: 0.8237030768445912
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [7/100], Train Loss: 0.4284, VAL Loss: 0.4585
# $$训练集准确率 accuracy: 0.8276232413274621 $$训练集精确率 precision: 0.8371229398251806 $$训练集召回率 recall: 0.8295314891679744 $$训练集 F1 评分 f1_score: 0.8269044617634196
# @@测试集准确率 accuracy: 0.8098918083462133 @@测试集精确率 precision: 0.8241056559860356 @@测试集召回率 recall: 0.8087490443425076 @@测试集 F1 评分 f1_score: 0.8073719601193805
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [8/100], Train Loss: 0.4176, VAL Loss: 0.4498
# $$训练集准确率 accuracy: 0.8263344431317796 $$训练集精确率 precision: 0.8372548403268419 $$训练集召回率 recall: 0.8283796744377269 $$训练集 F1 评分 f1_score: 0.8254681001898987
# @@测试集准确率 accuracy: 0.8191653786707882 @@测试集精确率 precision: 0.830454807138745 @@测试集召回率 recall: 0.8181574923547401 @@测试集 F1 评分 f1_score: 0.8172638460071502
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [9/100], Train Loss: 0.4116, VAL Loss: 0.4487
# $$训练集准确率 accuracy: 0.8365374288475996 $$训练集精确率 precision: 0.8438856278336572 $$训练集召回率 recall: 0.8382069839368216 $$训练集 F1 评分 f1_score: 0.8360627932254652
# @@测试集准确率 accuracy: 0.8160741885625966 @@测试集精确率 precision: 0.8305962962219859 @@测试集召回率 recall: 0.8149321483180427 @@测试集 F1 评分 f1_score: 0.8136362866195632
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [10/100], Train Loss: 0.4060, VAL Loss: 0.4290
# $$训练集准确率 accuracy: 0.8431962195252927 $$训练集精确率 precision: 0.8478878957733678 $$训练集召回率 recall: 0.8445300317998916 $$训练集 F1 评分 f1_score: 0.842957527603726
# @@测试集准确率 accuracy: 0.8384853168469861 @@测试集精确率 precision: 0.8385014278374535 @@测试集召回率 recall: 0.8384245986238532 @@测试集 F1 评分 f1_score: 0.8384504875826949
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [11/100], Train Loss: 0.3980, VAL Loss: 0.4172
# $$训练集准确率 accuracy: 0.8379336268929224 $$训练集精确率 precision: 0.8455522433793816 $$训练集召回率 recall: 0.8396309530393257 $$训练集 F1 评分 f1_score: 0.8374420908449831
# @@测试集准确率 accuracy: 0.8431221020092736 @@测试集精确率 precision: 0.8434593583181993 @@测试集召回率 recall: 0.8429448585626911 @@测试集 F1 评分 f1_score: 0.8430200072071125
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [12/100], Train Loss: 0.3920, VAL Loss: 0.4094
# $$训练集准确率 accuracy: 0.8369670282461604 $$训练集精确率 precision: 0.8467126532674158 $$训练集召回率 recall: 0.8388826266121414 $$训练集 F1 评分 f1_score: 0.8362849331291021
# @@测试集准确率 accuracy: 0.8462132921174652 @@测试集精确率 precision: 0.8463308509748138 @@测试集召回率 recall: 0.8461033065749235 @@测试集 F1 评分 f1_score: 0.8461558682551376
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [13/100], Train Loss: 0.3873, VAL Loss: 0.4037
# $$训练集准确率 accuracy: 0.8538288046396735 $$训练集精确率 precision: 0.8571494131144648 $$训练集召回率 recall: 0.8549494057381988 $$训练集 F1 评分 f1_score: 0.8537021134178049
# @@测试集准确率 accuracy: 0.8353941267387944 @@测试集精确率 precision: 0.8406944819351528 @@测试集召回率 recall: 0.834714258409786 @@测试集 F1 评分 f1_score: 0.8345394699322302
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [14/100], Train Loss: 0.3776, VAL Loss: 0.3928
# $$训练集准确率 accuracy: 0.8521104070454302 $$训练集精确率 precision: 0.8568035951294442 $$训练集召回率 recall: 0.8534365958097414 $$训练集 F1 评分 f1_score: 0.8518914527234807
# @@测试集准确率 accuracy: 0.8415765069551777 @@测试集精确率 precision: 0.845952366523241 @@测试集召回率 recall: 0.840964258409786 @@测试集 F1 评分 f1_score: 0.8408899653373207
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [15/100], Train Loss: 0.3644, VAL Loss: 0.3887
# $$训练集准确率 accuracy: 0.865857587799377 $$训练集精确率 precision: 0.8668184696353401 $$训练集召回率 recall: 0.8664830176687299 $$训练集 F1 评分 f1_score: 0.8658500056194602
# @@测试集准确率 accuracy: 0.8369397217928902 @@测试集精确率 precision: 0.8428207420543764 @@测试集召回率 recall: 0.8362265863914373 @@测试集 F1 评分 f1_score: 0.8360182747787273
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [16/100], Train Loss: 0.3662, VAL Loss: 0.5247
# $$训练集准确率 accuracy: 0.8665019868972184 $$训练集精确率 precision: 0.8678491078629745 $$训练集召回率 recall: 0.8672309978728981 $$训练集 F1 评分 f1_score: 0.866482668057587
# @@测试集准确率 accuracy: 0.7581143740340031 @@测试集精确率 precision: 0.8178262121711455 @@测试集召回率 recall: 0.7557530581039755 @@测试集 F1 评分 f1_score: 0.7450426070463878
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [17/100], Train Loss: 0.3554, VAL Loss: 0.3726
# $$训练集准确率 accuracy: 0.8678981849425411 $$训练集精确率 precision: 0.8697995467812907 $$训练集召回率 recall: 0.8687532943119991 $$训练集 F1 评分 f1_score: 0.8678576877928584
# @@测试集准确率 accuracy: 0.8554868624420402 @@测试集精确率 precision: 0.8580645239018914 @@测试集召回率 recall: 0.8550267584097859 @@测试集 F1 评分 f1_score: 0.8550983953382951
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [18/100], Train Loss: 0.3527, VAL Loss: 0.3676
# $$训练集准确率 accuracy: 0.8701535817849855 $$训练集精确率 precision: 0.8714495727956286 $$训练集召回率 recall: 0.8708697556099438 $$训练集 F1 评分 f1_score: 0.8701367509624238
# @@测试集准确率 accuracy: 0.8531684698608965 @@测试集精确率 precision: 0.8534227898966705 @@测试集召回率 recall: 0.8530174885321101 @@测试集 F1 评分 f1_score: 0.8530895062908715
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [19/100], Train Loss: 0.3453, VAL Loss: 0.3941
# $$训练集准确率 accuracy: 0.8638169906562131 $$训练集精确率 precision: 0.8674086398159604 $$训练集召回率 recall: 0.8649747778840862 $$训练集 F1 评分 f1_score: 0.8636874795872072
# @@测试集准确率 accuracy: 0.8315301391035549 @@测试集精确率 precision: 0.8498127530364372 @@测试集召回率 recall: 0.8302895642201835 @@测试集 F1 评分 f1_score: 0.8289144584421979
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [20/100], Train Loss: 0.3390, VAL Loss: 0.3692
# $$训练集准确率 accuracy: 0.8637095908065728 $$训练集精确率 precision: 0.867609095141801 $$训练集召回率 recall: 0.8649140272855127 $$训练集 F1 评分 f1_score: 0.8635622290413567
# @@测试集准确率 accuracy: 0.8562596599690881 @@测试集精确率 precision: 0.8574791246760726 @@测试集召回率 recall: 0.8559418004587156 @@测试集 F1 评分 f1_score: 0.8560447289848416
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [21/100], Train Loss: 0.3339, VAL Loss: 0.3703
# $$训练集准确率 accuracy: 0.8811083664482869 $$训练集精确率 precision: 0.8810323389801531 $$训练集召回率 recall: 0.8810780719975839 $$训练集 F1 评分 f1_score: 0.8810534858221977
# @@测试集准确率 accuracy: 0.8632148377125193 @@测试集精确率 precision: 0.8649441618766023 @@测试集召回率 recall: 0.8635918386850152 @@测试集 F1 评分 f1_score: 0.8631258190919158
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [22/100], Train Loss: 0.3301, VAL Loss: 0.3566
# $$训练集准确率 accuracy: 0.8808935667490065 $$训练集精确率 precision: 0.8809992529700095 $$训练集召回率 recall: 0.8811778073077801 $$训练集 F1 评分 f1_score: 0.8808864442314417
# @@测试集准确率 accuracy: 0.8639876352395672 @@测试集精确率 precision: 0.8639717125382262 @@测试集召回率 recall: 0.8639717125382262 @@测试集 F1 评分 f1_score: 0.8639717125382262
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [23/100], Train Loss: 0.3240, VAL Loss: 0.3516
# $$训练集准确率 accuracy: 0.881645365696488 $$训练集精确率 precision: 0.8816134426097897 $$训练集召回率 recall: 0.8818095489046474 $$训练集 F1 评分 f1_score: 0.8816253745958702
# @@测试集准确率 accuracy: 0.8624420401854714 @@测试集精确率 precision: 0.8625502008032129 @@测试集召回率 recall: 0.8623423165137615 @@测试集 F1 评分 f1_score: 0.8623947044555698
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [24/100], Train Loss: 0.3243, VAL Loss: 0.3598
# $$训练集准确率 accuracy: 0.8833637632907314 $$训练集精确率 precision: 0.8832785829584012 $$训练集召回率 recall: 0.8834010207023821 $$训练集 F1 评分 f1_score: 0.883323483889513
# @@测试集准确率 accuracy: 0.8585780525502318 @@测试集精确率 precision: 0.8634661057861425 @@测试集召回率 recall: 0.8579510703363915 @@测试集 F1 评分 f1_score: 0.8579358761076918
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [25/100], Train Loss: 0.3222, VAL Loss: 0.3575
# $$训练集准确率 accuracy: 0.8833637632907314 $$训练集精确率 precision: 0.8833831850178816 $$训练集召回率 recall: 0.8835829262750863 $$训练集 F1 评分 f1_score: 0.883350575855639
# @@测试集准确率 accuracy: 0.8593508500772797 @@测试集精确率 precision: 0.8613323713323713 @@测试集召回率 recall: 0.8589497324159021 @@测试集 F1 评分 f1_score: 0.8590478060084892
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [26/100], Train Loss: 0.3157, VAL Loss: 0.3537
# $$训练集准确率 accuracy: 0.8828267640425304 $$训练集精确率 precision: 0.8831826707175274 $$训练集召回率 recall: 0.8832447587144102 $$训练集 F1 评分 f1_score: 0.8828263261350096
# @@测试集准确率 accuracy: 0.866306027820711 @@测试集精确率 precision: 0.8665324459632228 @@测试集召回率 recall: 0.8664492545871559 @@测试集 F1 评分 f1_score: 0.8663040316863662
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [27/100], Train Loss: 0.3114, VAL Loss: 0.3769
# $$训练集准确率 accuracy: 0.8876597572763398 $$训练集精确率 precision: 0.8875759698691119 $$训练集召回率 recall: 0.8876795985733396 $$训练集 F1 评分 f1_score: 0.887617289062006
# @@测试集准确率 accuracy: 0.8500772797527048 @@测试集精确率 precision: 0.856339552673475 @@测试集召回率 recall: 0.8507955848623854 @@测试集 F1 评分 f1_score: 0.8495853705301505
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [28/100], Train Loss: 0.3107, VAL Loss: 0.3404
# $$训练集准确率 accuracy: 0.8859413596820964 $$训练集精确率 precision: 0.8859056683655842 $$训练集召回率 recall: 0.8861028758760943 $$训练集 F1 评分 f1_score: 0.8859214519606876
# @@测试集准确率 accuracy: 0.8717156105100463 @@测试集精确率 precision: 0.8720620885009953 @@测试集召回率 recall: 0.8715500764525994 @@测试集 F1 评分 f1_score: 0.8716371102872454
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [29/100], Train Loss: 0.3075, VAL Loss: 0.3378
# $$训练集准确率 accuracy: 0.8846525614864139 $$训练集精确率 precision: 0.8848993157268379 $$训练集召回率 recall: 0.8850198902814645 $$训练集 F1 评分 f1_score: 0.8846505377584402
# @@测试集准确率 accuracy: 0.8732612055641422 @@测试集精确率 precision: 0.873246368501529 @@测试集召回率 recall: 0.873246368501529 @@测试集 F1 评分 f1_score: 0.873246368501529
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [30/100], Train Loss: 0.3068, VAL Loss: 0.3365
# $$训练集准确率 accuracy: 0.889807754269144 $$训练集精确率 precision: 0.8898176036324106 $$训练集召回率 recall: 0.8896664801370933 $$训练集 F1 评分 f1_score: 0.8897301549309119
# @@测试集准确率 accuracy: 0.8740340030911901 @@测试集精确率 precision: 0.8740817452752435 @@测试集召回率 recall: 0.8741112385321101 @@测试集 F1 评分 f1_score: 0.8740333260273514
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [31/100], Train Loss: 0.3019, VAL Loss: 0.3669
# $$训练集准确率 accuracy: 0.8880893566749006 $$训练集精确率 precision: 0.8880061720999446 $$训练集召回率 recall: 0.8881045065403375 $$训练集 F1 评分 f1_score: 0.888046110399169
# @@测试集准确率 accuracy: 0.8438948995363215 @@测试集精确率 precision: 0.8579068143270479 @@测试集召回率 recall: 0.8428230122324158 @@测试集 F1 评分 f1_score: 0.8420459791786015
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [32/100], Train Loss: 0.3045, VAL Loss: 0.3359
# $$训练集准确率 accuracy: 0.8863709590806573 $$训练集精确率 precision: 0.8866084139885801 $$训练集召回率 recall: 0.8867342712499454 $$训练集 F1 评分 f1_score: 0.8863687557847781
# @@测试集准确率 accuracy: 0.8717156105100463 @@测试集精确率 precision: 0.8719150847814036 @@测试集召回率 recall: 0.8718511085626912 @@测试集 F1 评分 f1_score: 0.8717143846824572
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [33/100], Train Loss: 0.2989, VAL Loss: 0.3325
# $$训练集准确率 accuracy: 0.8905595532166255 $$训练集精确率 precision: 0.8905480683112992 $$训练集召回率 recall: 0.890440796372026 $$训练集 F1 评分 f1_score: 0.8904880010206135
# @@测试集准确率 accuracy: 0.8686244204018547 @@测试集精确率 precision: 0.8690413515841868 @@测试集召回率 recall: 0.8684418004587156 @@测试集 F1 评分 f1_score: 0.868533658443297
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [34/100], Train Loss: 0.2960, VAL Loss: 0.3262
# $$训练集准确率 accuracy: 0.8897003544195038 $$训练集精确率 precision: 0.8896439933591 $$训练集召回率 recall: 0.8896401441063286 $$训练集 F1 评分 f1_score: 0.8896420584560051
# @@测试集准确率 accuracy: 0.8701700154559505 @@测试集精确率 precision: 0.8706722391375117 @@测试集召回率 recall: 0.8699708524464832 @@测试集 F1 评分 f1_score: 0.8700694502552089
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [35/100], Train Loss: 0.2901, VAL Loss: 0.3258
# $$训练集准确率 accuracy: 0.8909891526151863 $$训练集精确率 precision: 0.8911137750613596 $$训练集召回率 recall: 0.8907624606355972 $$训练集 F1 评分 f1_score: 0.8908890664994966
# @@测试集准确率 accuracy: 0.8771251931993818 @@测试集精确率 precision: 0.8771061627881975 @@测试集召回率 recall: 0.8771358944954128 @@测试集 F1 评分 f1_score: 0.8771163132385483
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [36/100], Train Loss: 0.2893, VAL Loss: 0.3214
# $$训练集准确率 accuracy: 0.8915261518633874 $$训练集精确率 precision: 0.8915044124305478 $$训练集召回率 recall: 0.8914201920402128 $$训练集 F1 评分 f1_score: 0.8914581820182983
# @@测试集准确率 accuracy: 0.8763523956723338 @@测试集精确率 precision: 0.8768670649738611 @@测试集召回率 recall: 0.8761539564220183 @@测试集 F1 评分 f1_score: 0.876256619290675
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [37/100], Train Loss: 0.2896, VAL Loss: 0.3963
# $$训练集准确率 accuracy: 0.8935667490065514 $$训练集精确率 precision: 0.894153822442857 $$训练集召回率 recall: 0.89313491923171 $$训练集 F1 评分 f1_score: 0.8934020395961149
# @@测试集准确率 accuracy: 0.8222565687789799 @@测试集精确率 precision: 0.8420934686061199 @@测试集召回率 recall: 0.8209480122324159 @@测试集 F1 评分 f1_score: 0.819209190553829
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [38/100], Train Loss: 0.2884, VAL Loss: 0.3254
# $$训练集准确率 accuracy: 0.8961443453979164 $$训练集精确率 precision: 0.8962531675979848 $$训练集召回率 recall: 0.8959351017420187 $$训练集 F1 评分 f1_score: 0.8960530103570776
# @@测试集准确率 accuracy: 0.8740340030911901 @@测试集精确率 precision: 0.8742070063009397 @@测试集召回率 recall: 0.8741614105504587 @@测试集 F1 评分 f1_score: 0.8740333260273514
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [39/100], Train Loss: 0.2877, VAL Loss: 0.3189
# $$训练集准确率 accuracy: 0.8939963484051122 $$训练集精确率 precision: 0.8939422791596983 $$训练集召回率 recall: 0.8939383874446054 $$训练集 F1 评分 f1_score: 0.8939403229757322
# @@测试集准确率 accuracy: 0.8786707882534776 @@测试集精确率 precision: 0.8787955894826124 @@测试集召回率 recall: 0.8787820145259939 @@测试集 F1 评分 f1_score: 0.8786707157936856
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [40/100], Train Loss: 0.2868, VAL Loss: 0.3126
# $$训练集准确率 accuracy: 0.8941037482547525 $$训练集精确率 precision: 0.8947868239449348 $$训练集召回率 recall: 0.8936402432646006 $$训练集 F1 评分 f1_score: 0.8939280018227387
# @@测试集准确率 accuracy: 0.875579598145286 @@测试集精确率 precision: 0.8758301943198804 @@测试集召回率 recall: 0.8754396024464832 @@测试集 F1 评分 f1_score: 0.8755170755170755
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [41/100], Train Loss: 0.2829, VAL Loss: 0.3193
# $$训练集准确率 accuracy: 0.8957147459993556 $$训练集精确率 precision: 0.8956338270857716 $$训练集召回率 recall: 0.8957805939506622 $$训练集 F1 评分 f1_score: 0.8956823827066158
# @@测试集准确率 accuracy: 0.8701700154559505 @@测试集精确率 precision: 0.8733952083092011 @@测试集召回率 recall: 0.8696698203363915 @@测试集 F1 评分 f1_score: 0.8697668177123645
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [42/100], Train Loss: 0.2809, VAL Loss: 0.3078
# $$训练集准确率 accuracy: 0.8950703469015143 $$训练集精确率 precision: 0.8953989929148548 $$训练集召回率 recall: 0.8947425481035334 $$训练集 F1 评分 f1_score: 0.8949431367421166
# @@测试集准确率 accuracy: 0.874806800618238 @@测试集精确率 precision: 0.875088499808649 @@测试集召回率 recall: 0.8746583524464833 @@测试集 F1 评分 f1_score: 0.8747394737848484
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [43/100], Train Loss: 0.2803, VAL Loss: 0.3471
# $$训练集准确率 accuracy: 0.8945333476533133 $$训练集精确率 precision: 0.8954087248598244 $$训练集召回率 recall: 0.8940110711964702 $$训练集 F1 评分 f1_score: 0.8943354015549706
# @@测试集准确率 accuracy: 0.8624420401854714 @@测试集精确率 precision: 0.8712400875034181 @@测试集召回率 recall: 0.8632788608562691 @@测试集 F1 评分 f1_score: 0.8618029005959109
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [44/100], Train Loss: 0.2749, VAL Loss: 0.3010
# $$训练集准确率 accuracy: 0.8981849425410804 $$训练集精确率 precision: 0.8984513352064963 $$训练集召回率 recall: 0.8978907309081781 $$训练集 F1 评分 f1_score: 0.8980712256634102
# @@测试集准确率 accuracy: 0.8825347758887172 @@测试集精确率 precision: 0.8826568177471792 @@测试集召回率 recall: 0.8824374044342507 @@测试集 F1 评分 f1_score: 0.882494354366554
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [45/100], Train Loss: 0.2742, VAL Loss: 0.3255
# $$训练集准确率 accuracy: 0.898507142090001 $$训练集精确率 precision: 0.8984773247031927 $$训练集召回率 recall: 0.8986826121907987 $$训练集 F1 评分 f1_score: 0.8984902813177169
# @@测试集准确率 accuracy: 0.8670788253477589 @@测试集精确率 precision: 0.8734002454417953 @@测试集召回率 recall: 0.8663775802752294 @@测试集 F1 评分 f1_score: 0.8663431858853485
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [46/100], Train Loss: 0.2732, VAL Loss: 0.3011
# $$训练集准确率 accuracy: 0.8986145419396413 $$训练集精确率 precision: 0.8985816383450176 $$训练集召回率 recall: 0.8985319590156888 $$训练集 F1 评分 f1_score: 0.898555303756646
# @@测试集准确率 accuracy: 0.8794435857805255 @@测试集精确率 precision: 0.880629269322281 @@测试集召回率 recall: 0.8791451643730888 @@测试集 F1 评分 f1_score: 0.8792774733095234
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [47/100], Train Loss: 0.2708, VAL Loss: 0.3657
# $$训练集准确率 accuracy: 0.9000107399849641 $$训练集精确率 precision: 0.900199223385107 $$训练集召回率 recall: 0.8997592734449993 $$训练集 F1 评分 f1_score: 0.8999109496279716
# @@测试集准确率 accuracy: 0.8423493044822257 @@测试集精确率 precision: 0.8581815172247748 @@测试集召回率 recall: 0.8412103402140673 @@测试集 F1 评分 f1_score: 0.8402596742453399
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [48/100], Train Loss: 0.2691, VAL Loss: 0.2961
# $$训练集准确率 accuracy: 0.901514337879927 $$训练集精确率 precision: 0.90292649756189 $$训练集召回率 recall: 0.9008654329001791 $$训练集 F1 评分 f1_score: 0.9012775535591941
# @@测试集准确率 accuracy: 0.8802163833075735 @@测试集精确率 precision: 0.8802468545756514 @@测试集召回率 recall: 0.8801605504587156 @@测试集 F1 评分 f1_score: 0.8801905529919507
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [49/100], Train Loss: 0.2694, VAL Loss: 0.3009
# $$训练集准确率 accuracy: 0.8999033401353238 $$训练集精确率 precision: 0.9008350638315222 $$训练集召回率 recall: 0.8993740426356565 $$训练集 F1 评分 f1_score: 0.8997117176987637
# @@测试集准确率 accuracy: 0.8763523956723338 @@测试集精确率 precision: 0.8769250636107975 @@测试集召回率 recall: 0.8765720565749235 @@测试集 F1 评分 f1_score: 0.8763379204892967
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [50/100], Train Loss: 0.2688, VAL Loss: 0.2975
# $$训练集准确率 accuracy: 0.901514337879927 $$训练集精确率 precision: 0.9026068339341341 $$训练集召回率 recall: 0.9009440947694565 $$训练集 F1 评分 f1_score: 0.9013096870141917
# @@测试集准确率 accuracy: 0.8794435857805255 @@测试集精确率 precision: 0.8799300893249937 @@测试集召回率 recall: 0.8796468845565749 @@测试集 F1 评分 f1_score: 0.8794332171449186
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [51/100], Train Loss: 0.2666, VAL Loss: 0.2892
# $$训练集准确率 accuracy: 0.9009773386317259 $$训练集精确率 precision: 0.9016994600971464 $$训练集召回率 recall: 0.9005125162390135 $$训练集 F1 评分 f1_score: 0.9008112577348747
# @@测试集准确率 accuracy: 0.8809891808346213 @@测试集精确率 precision: 0.8813495253406829 @@测试集召回率 recall: 0.8808247324159022 @@测试集 F1 评分 f1_score: 0.8809163553267216
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [52/100], Train Loss: 0.2629, VAL Loss: 0.3208
# $$训练集准确率 accuracy: 0.9012995381806466 $$训练集精确率 precision: 0.9029072841421997 $$训练集召回率 recall: 0.9006062734317967 $$训练集 F1 评分 f1_score: 0.901043083763863
# @@测试集准确率 accuracy: 0.8763523956723338 @@测试集精确率 precision: 0.8804866872467683 @@测试集召回率 recall: 0.8769232607033639 @@测试集 F1 评分 f1_score: 0.876120385328786
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [53/100], Train Loss: 0.2620, VAL Loss: 0.2945
# $$训练集准确率 accuracy: 0.9021587369777683 $$训练集精确率 precision: 0.9020979487420939 $$训练集召回率 recall: 0.9021247152546508 $$训练集 F1 评分 f1_score: 0.9021108214284251
# @@测试集准确率 accuracy: 0.884080370942813 @@测试集精确率 precision: 0.8858839810863799 @@测试集召回率 recall: 0.8837155963302752 @@测试集 F1 评分 f1_score: 0.8838628612457369
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [54/100], Train Loss: 0.2616, VAL Loss: 0.3045
# $$训练集准确率 accuracy: 0.9016217377295672 $$训练集精确率 precision: 0.9017574548715696 $$训练集召回率 recall: 0.9014030710812471 $$训练集 F1 评分 f1_score: 0.901532053750957
# @@测试集准确率 accuracy: 0.8717156105100463 @@测试集精确率 precision: 0.8766708376983665 @@测试集召回率 recall: 0.8710985282874617 @@测试集 F1 评分 f1_score: 0.871146463192245
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [55/100], Train Loss: 0.2562, VAL Loss: 0.3532
# $$训练集准确率 accuracy: 0.9006551390828053 $$训练集精确率 precision: 0.9005936637096573 $$训练集召回率 recall: 0.9006203300862539 $$训练集 F1 评分 f1_score: 0.9006064871803439
# @@测试集准确率 accuracy: 0.8539412673879444 @@测试集精确率 precision: 0.8681618206064534 @@测试集召回率 recall: 0.8528789181957186 @@测试集 F1 评分 f1_score: 0.8522362494449026
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [56/100], Train Loss: 0.2578, VAL Loss: 0.2866
# $$训练集准确率 accuracy: 0.9043067339705725 $$训练集精确率 precision: 0.9047264211986397 $$训练集召回率 recall: 0.9039542730798494 $$训练集 F1 评分 f1_score: 0.9041819573565237
# @@测试集准确率 accuracy: 0.883307573415765 @@测试集精确率 precision: 0.8839354260089686 @@测试集召回率 recall: 0.8835364105504587 @@测试集 F1 评分 f1_score: 0.8832918909265319
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [57/100], Train Loss: 0.2572, VAL Loss: 0.3177
# $$训练集准确率 accuracy: 0.9039845344216518 $$训练集精确率 precision: 0.9046861625026446 $$训练集召回率 recall: 0.903531119309467 $$训练集 F1 评分 f1_score: 0.9038268663288559
# @@测试集准确率 accuracy: 0.8771251931993818 @@测试集精确率 precision: 0.8792470354450612 @@测试集召回率 recall: 0.8775372706422018 @@测试集 F1 评分 f1_score: 0.8770246499393031
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [58/100], Train Loss: 0.2567, VAL Loss: 0.2791
# $$训练集准确率 accuracy: 0.9048437332187735 $$训练集精确率 precision: 0.9059612869095919 $$训练集召回率 recall: 0.904272775173206 $$训练集 F1 评分 f1_score: 0.9046450650076723
# @@测试集准确率 accuracy: 0.8856259659969088 @@测试集精确率 precision: 0.8863551446637287 @@测试集召回率 recall: 0.8853951643730886 @@测试集 F1 评分 f1_score: 0.8855165718576119
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [59/100], Train Loss: 0.2531, VAL Loss: 0.3399
# $$训练集准确率 accuracy: 0.9057029320158951 $$训练集精确率 precision: 0.9074901179344974 $$训练集召回率 recall: 0.9049800164691364 $$训练集 F1 评分 f1_score: 0.9054442577786611
# @@测试集准确率 accuracy: 0.8593508500772797 @@测试集精确率 precision: 0.8681695061631467 @@测试集召回率 recall: 0.8585149082568808 @@测试集 F1 评分 f1_score: 0.8582892269774449
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [60/100], Train Loss: 0.2550, VAL Loss: 0.3083
# $$训练集准确率 accuracy: 0.9036623348727312 $$训练集精确率 precision: 0.9045835581404162 $$训练集召回率 recall: 0.9031423801068934 $$训练集 F1 评分 f1_score: 0.9034806224623043
# @@测试集准确率 accuracy: 0.8686244204018547 @@测试集精确率 precision: 0.8762707722385141 @@测试集召回率 recall: 0.8678564602446484 @@测试集 F1 评分 f1_score: 0.8677702840792969
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [61/100], Train Loss: 0.2504, VAL Loss: 0.2774
# $$训练集准确率 accuracy: 0.9067769305122972 $$训练集精确率 precision: 0.907059933819838 $$训练集召回率 recall: 0.9064872175847316 $$训练集 F1 评分 f1_score: 0.9066728099956118
# @@测试集准确率 accuracy: 0.8871715610510046 @@测试集精确率 precision: 0.8875052583272782 @@测试集召回率 recall: 0.8873423165137615 @@测试集 F1 评分 f1_score: 0.8871672483773021
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [62/100], Train Loss: 0.2553, VAL Loss: 0.2846
# $$训练集准确率 accuracy: 0.9074213296101385 $$训练集精确率 precision: 0.9075819554530955 $$训练集召回率 recall: 0.907195866854261 $$训练集 F1 评分 f1_score: 0.9073345105478712
# @@测试集准确率 accuracy: 0.884853168469861 @@测试集精确率 precision: 0.8858098486208341 @@测试集召回率 recall: 0.8851323585626911 @@测试集 F1 评分 f1_score: 0.8848228339989068
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [63/100], Train Loss: 0.2490, VAL Loss: 0.3019
# $$训练集准确率 accuracy: 0.9070991300612179 $$训练集精确率 precision: 0.9071275855562141 $$训练集召回率 recall: 0.9069644513902424 $$训练集 F1 评分 f1_score: 0.9070331764316221
# @@测试集准确率 accuracy: 0.8670788253477589 @@测试集精确率 precision: 0.8746896383186706 @@测试集召回率 recall: 0.8663106842507645 @@测试集 F1 评分 f1_score: 0.8662146403625828
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [64/100], Train Loss: 0.2485, VAL Loss: 0.3587
# $$训练集准确率 accuracy: 0.9051659327676941 $$训练集精确率 precision: 0.9050879851420468 $$训练集召回率 recall: 0.9052465620285308 $$训练集 F1 评分 f1_score: 0.90513792103649
# @@测试集准确率 accuracy: 0.8500772797527048 @@测试集精确率 precision: 0.8715791494866199 @@测试集召回率 recall: 0.8513809250764526 @@测试集 F1 评分 f1_score: 0.8481973755820282
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [65/100], Train Loss: 0.2471, VAL Loss: 0.2745
# $$训练集准确率 accuracy: 0.9074213296101385 $$训练集精确率 precision: 0.9078181016016071 $$训练集召回率 recall: 0.9070827904171748 $$训练集 F1 评分 f1_score: 0.9073041846893856
# @@测试集准确率 accuracy: 0.8902627511591963 @@测试集精确率 precision: 0.8904405998355043 @@测试集召回率 recall: 0.8901495603975536 @@测试集 F1 评分 f1_score: 0.8902184303603862
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [66/100], Train Loss: 0.2455, VAL Loss: 0.3136
# $$训练集准确率 accuracy: 0.9054881323166147 $$训练集精确率 precision: 0.9078360274836834 $$训练集召回率 recall: 0.9046569442319661 $$训练集 F1 评分 f1_score: 0.9051797442877649
# @@测试集准确率 accuracy: 0.8809891808346213 @@测试集精确率 precision: 0.8880695618381425 @@测试集召回率 recall: 0.8817278287461774 @@测试集 F1 评分 f1_score: 0.8805772296333585
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [67/100], Train Loss: 0.2431, VAL Loss: 0.2807
# $$训练集准确率 accuracy: 0.9062399312640962 $$训练集精确率 precision: 0.9061630489362802 $$训练集召回率 recall: 0.906257210094312 $$训练集 F1 评分 f1_score: 0.906202500861844
# @@测试集准确率 accuracy: 0.8863987635239567 @@测试集精确率 precision: 0.8886546080881805 @@测试集召回率 recall: 0.8859924503058103 @@测试集 F1 评分 f1_score: 0.8861457519684686
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [68/100], Train Loss: 0.2419, VAL Loss: 0.2940
# $$训练集准确率 accuracy: 0.9068843303619375 $$训练集精确率 precision: 0.9102167717097126 $$训练集召回率 recall: 0.9058940913949363 $$训练集 F1 评分 f1_score: 0.9065012360216798
# @@测试集准确率 accuracy: 0.8887171561051005 @@测试集精确率 precision: 0.8937725928360171 @@测试集召回率 recall: 0.8893396406727829 @@测试集 F1 评分 f1_score: 0.8884610964256981
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [69/100], Train Loss: 0.2460, VAL Loss: 0.2975
# $$训练集准确率 accuracy: 0.9065621308130168 $$训练集精确率 precision: 0.9065561572962817 $$训练集召回率 recall: 0.9064591273573517 $$训练集 F1 评分 f1_score: 0.9065025724526375
# @@测试集准确率 accuracy: 0.8724884080370943 @@测试集精确率 precision: 0.8790708608093853 @@测试集召回率 recall: 0.8717794342507645 @@测试集 F1 评分 f1_score: 0.8717678452061137
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [70/100], Train Loss: 0.2440, VAL Loss: 0.2656
# $$训练集准确率 accuracy: 0.908710127805821 $$训练集精确率 precision: 0.9086723693210441 $$训练集召回率 recall: 0.9086475799611289 $$训练集 F1 评分 f1_score: 0.9086595967350655
# @@测试集准确率 accuracy: 0.8902627511591963 @@测试集精确率 precision: 0.8904405998355043 @@测试集召回率 recall: 0.8901495603975536 @@测试集 F1 评分 f1_score: 0.8902184303603862
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [71/100], Train Loss: 0.2414, VAL Loss: 0.3378
# $$训练集准确率 accuracy: 0.9049511330684137 $$训练集精确率 precision: 0.9084921276060953 $$训练集召回率 recall: 0.9039254673249029 $$训练集 F1 评分 f1_score: 0.9045414179442026
# @@测试集准确率 accuracy: 0.8639876352395672 @@测试集精确率 precision: 0.8801795167774549 @@测试集召回率 recall: 0.8651089449541285 @@测试集 F1 评分 f1_score: 0.8627677831125509
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [72/100], Train Loss: 0.2356, VAL Loss: 0.2683
# $$训练集准确率 accuracy: 0.9101063258511438 $$训练集精确率 precision: 0.9114814043734539 $$训练集召回率 recall: 0.9094815850440521 $$训练集 F1 评分 f1_score: 0.9098977331576588
# @@测试集准确率 accuracy: 0.89258114374034 @@测试集精确率 precision: 0.8931756318393906 @@测试集召回率 recall: 0.8923762423547401 @@测试集 F1 评分 f1_score: 0.8924932474312146
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [73/100], Train Loss: 0.2391, VAL Loss: 0.2650
# $$训练集准确率 accuracy: 0.9104285254000645 $$训练集精确率 precision: 0.9114961021482328 $$训练集召回率 recall: 0.9098801569802853 $$训练集 F1 评分 f1_score: 0.9102485052385996
# @@测试集准确率 accuracy: 0.8887171561051005 @@测试集精确率 precision: 0.8888007189567478 @@测试集召回率 recall: 0.8886372324159022 @@测试集 F1 评分 f1_score: 0.8886849802144865
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [74/100], Train Loss: 0.2385, VAL Loss: 0.2774
# $$训练集准确率 accuracy: 0.9097841263022232 $$训练集精确率 precision: 0.9111893064254233 $$训练集召回率 recall: 0.9091518422434365 $$训练集 F1 评分 f1_score: 0.9095719662967336
# @@测试集准确率 accuracy: 0.8979907264296755 @@测试集精确率 precision: 0.8999395579092793 @@测试集召回率 recall: 0.8983801605504587 @@测试集 F1 评分 f1_score: 0.8979202524383247
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [75/100], Train Loss: 0.2361, VAL Loss: 0.3383
# $$训练集准确率 accuracy: 0.908710127805821 $$训练集精确率 precision: 0.9102621340720731 $$训练集召回率 recall: 0.9080428668410585 $$训练集 F1 评分 f1_score: 0.9084818727652247
# @@测试集准确率 accuracy: 0.8632148377125193 @@测试集精确率 precision: 0.8806635667273177 @@测试集召回率 recall: 0.8643778669724771 @@测试集 F1 评分 f1_score: 0.8618844399740216
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [76/100], Train Loss: 0.2315, VAL Loss: 0.2870
# $$训练集准确率 accuracy: 0.912254322843948 $$训练集精确率 precision: 0.9138387908899002 $$训练集召回率 recall: 0.9115864594117219 $$训练集 F1 评分 f1_score: 0.9120339824554495
# @@测试集准确率 accuracy: 0.8802163833075735 @@测试集精确率 precision: 0.8838883051318285 @@测试集召回率 recall: 0.8796922782874618 @@测试集 F1 评分 f1_score: 0.8798126330662969
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [77/100], Train Loss: 0.2364, VAL Loss: 0.3264
# $$训练集准确率 accuracy: 0.9131135216410697 $$训练集精确率 precision: 0.9140734978555187 $$训练集召回率 recall: 0.9125985154511023 $$训练集 F1 评分 f1_score: 0.9129496360891909
# @@测试集准确率 accuracy: 0.8632148377125193 @@测试集精确率 precision: 0.87232217157249 @@测试集召回率 recall: 0.8623709862385321 @@测试集 F1 评分 f1_score: 0.8621637187234266
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [78/100], Train Loss: 0.2359, VAL Loss: 0.2873
# $$训练集准确率 accuracy: 0.9104285254000645 $$训练集精确率 precision: 0.9111836192890839 $$训练集召回率 recall: 0.9099686515832225 $$训练集 F1 评分 f1_score: 0.9102782960421751
# @@测试集准确率 accuracy: 0.8740340030911901 @@测试集精确率 precision: 0.8783648365054353 @@测试集召回率 recall: 0.873459002293578 @@测试集 F1 评分 f1_score: 0.873538484598666
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [79/100], Train Loss: 0.2338, VAL Loss: 0.2892
# $$训练集准确率 accuracy: 0.9107507249489851 $$训练集精确率 precision: 0.9129661359646896 $$训练集召回率 recall: 0.9099542487057491 $$训练集 F1 评分 f1_score: 0.9104736368912845
# @@测试集准确率 accuracy: 0.8786707882534776 @@测试集精确率 precision: 0.8820949999155105 @@测试集召回率 recall: 0.8781632262996942 @@测试集 F1 评分 f1_score: 0.8782834174202133
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [80/100], Train Loss: 0.2268, VAL Loss: 0.2679
# $$训练集准确率 accuracy: 0.9136505208892708 $$训练集精确率 precision: 0.9146037565121612 $$训练集召回率 recall: 0.9131382540518018 $$训练集 F1 评分 f1_score: 0.9134884550409331
# @@测试集准确率 accuracy: 0.8918083462132921 @@测试集精确率 precision: 0.8923541295647345 @@测试集召回率 recall: 0.8916117163608562 @@测试集 F1 评分 f1_score: 0.8917245418793407
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [81/100], Train Loss: 0.2301, VAL Loss: 0.2691
# $$训练集准确率 accuracy: 0.909676726452583 $$训练集精确率 precision: 0.911291054848983 $$训练集召回率 recall: 0.9089976806750961 $$训练集 F1 评分 f1_score: 0.9094459929092298
# @@测试集准确率 accuracy: 0.8902627511591963 @@测试集精确率 precision: 0.8902835923610712 @@测试集召回率 recall: 0.8902164564220183 @@测试集 F1 评分 f1_score: 0.8902415131126233
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [82/100], Train Loss: 0.2293, VAL Loss: 0.2694
# $$训练集准确率 accuracy: 0.9131135216410697 $$训练集精确率 precision: 0.9142216287273125 $$训练集召回率 recall: 0.9125591845164636 $$训练集 F1 评分 f1_score: 0.912936371014412
# @@测试集准确率 accuracy: 0.8887171561051005 @@测试集精确率 precision: 0.8891691394658754 @@测试集召回率 recall: 0.8885368883792049 @@测试集 F1 评分 f1_score: 0.8886402753872633
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [83/100], Train Loss: 0.2278, VAL Loss: 0.2719
# $$训练集准确率 accuracy: 0.9131135216410697 $$训练集精确率 precision: 0.9134472004833523 $$训练集召回率 recall: 0.9128099192247854 $$训练集 F1 评分 f1_score: 0.9130120556142274
# @@测试集准确率 accuracy: 0.8972179289026275 @@测试集精确率 precision: 0.8972050023291647 @@测试集召回率 recall: 0.8972477064220183 @@测试集 F1 评分 f1_score: 0.8972129566310609
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [84/100], Train Loss: 0.2276, VAL Loss: 0.2628
# $$训练集准确率 accuracy: 0.9134357211899903 $$训练集精确率 precision: 0.9137986983562253 $$训练集召回率 recall: 0.9131199965580816 $$训练集 F1 评分 f1_score: 0.913331423652638
# @@测试集准确率 accuracy: 0.9010819165378671 @@测试集精确率 precision: 0.9011476788410451 @@测试集召回率 recall: 0.9011706804281345 @@测试集 F1 评分 f1_score: 0.901081680235447
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [85/100], Train Loss: 0.2231, VAL Loss: 0.2662
# $$训练集准确率 accuracy: 0.9146171195360326 $$训练集精确率 precision: 0.9149099160568832 $$训练集召回率 recall: 0.9143339698605017 $$训练集 F1 评分 f1_score: 0.9145223686645079
# @@测试集准确率 accuracy: 0.9003091190108191 @@测试集精确率 precision: 0.900303432127967 @@测试集召回率 recall: 0.9002890863914372 @@测试集 F1 评分 f1_score: 0.9002957213875671
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [86/100], Train Loss: 0.2255, VAL Loss: 0.2667
# $$训练集准确率 accuracy: 0.9124691225432284 $$训练集精确率 precision: 0.9123966363510322 $$训练集召回率 recall: 0.9124798302011538 $$训练集 F1 评分 f1_score: 0.9124326591811333
# @@测试集准确率 accuracy: 0.8887171561051005 @@测试集精确率 precision: 0.8888936707408045 @@测试集召回率 recall: 0.8886037844036698 @@测试集 F1 评分 f1_score: 0.8886722110696874
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [87/100], Train Loss: 0.2242, VAL Loss: 0.2785
# $$训练集准确率 accuracy: 0.914831919235313 $$训练集精确率 precision: 0.9148990740634679 $$训练集召回率 recall: 0.9146767075649913 $$训练集 F1 评分 f1_score: 0.9147664771397594
# @@测试集准确率 accuracy: 0.8995363214837713 @@测试集精确率 precision: 0.900234404898584 @@测试集召回率 recall: 0.8997754204892967 @@测试集 F1 评分 f1_score: 0.8995209595145086
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [88/100], Train Loss: 0.2253, VAL Loss: 0.2785
# $$训练集准确率 accuracy: 0.9146171195360326 $$训练集精确率 precision: 0.9150493036604883 $$训练集召回率 recall: 0.9142749734585436 $$训练集 F1 评分 f1_score: 0.9145071100138231
# @@测试集准确率 accuracy: 0.8871715610510046 @@测试集精确率 precision: 0.8881315310133256 @@测试集召回率 recall: 0.8869074923547401 @@测试集 F1 评分 f1_score: 0.887040956651719
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [89/100], Train Loss: 0.2216, VAL Loss: 0.2677
# $$训练集准确率 accuracy: 0.9144023198367522 $$训练集精确率 precision: 0.9146947051506573 $$训练集召回率 recall: 0.9141190576935878 $$训练集 F1 评分 f1_score: 0.9143073305982552
# @@测试集准确率 accuracy: 0.901854714064915 @@测试集精确率 precision: 0.9020933650365024 @@测试集召回率 recall: 0.9020021024464833 @@测试集 F1 评分 f1_score: 0.9018532486946156
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [90/100], Train Loss: 0.2237, VAL Loss: 0.3207
# $$训练集准确率 accuracy: 0.9120395231446676 $$训练集精确率 precision: 0.9120407563459458 $$训练集召回率 recall: 0.9122564932741793 $$训练集 F1 评分 f1_score: 0.9120281216197065
# @@测试集准确率 accuracy: 0.8732612055641422 @@测试集精确率 precision: 0.8813623999530342 @@测试集召回率 recall: 0.8724770642201836 @@测试集 F1 评分 f1_score: 0.8724050024050024
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [91/100], Train Loss: 0.2191, VAL Loss: 0.2714
# $$训练集准确率 accuracy: 0.9160133175813554 $$训练集精确率 precision: 0.9166184943547233 $$训练集召回率 recall: 0.9156104479581105 $$训练集 F1 评分 f1_score: 0.915888276484119
# @@测试集准确率 accuracy: 0.9057187017001546 @@测试集精确率 precision: 0.9067784033243331 @@测试集召回率 recall: 0.9060086964831804 @@测试集 F1 评分 f1_score: 0.9056914415706065
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [92/100], Train Loss: 0.2218, VAL Loss: 0.3352
# $$训练集准确率 accuracy: 0.9169799162281173 $$训练集精确率 precision: 0.9173330683077172 $$训练集召回率 recall: 0.9166734218624046 $$训练集 F1 评分 f1_score: 0.9168817405875979
# @@测试集准确率 accuracy: 0.8670788253477589 @@测试集精确率 precision: 0.8753819709702062 @@测试集召回率 recall: 0.8662772362385321 @@测试集 F1 评分 f1_score: 0.8661464109330683
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [93/100], Train Loss: 0.2211, VAL Loss: 0.2803
# $$训练集准确率 accuracy: 0.9171947159273977 $$训练集精确率 precision: 0.9184202691006753 $$训练集召回率 recall: 0.9166179338536773 $$训练集 F1 评分 f1_score: 0.9170177337437793
# @@测试集准确率 accuracy: 0.9034003091190108 @@测试集精确率 precision: 0.9052838188144621 @@测试集召回率 recall: 0.9037820145259938 @@测试集 F1 评分 f1_score: 0.9033374428615224
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [94/100], Train Loss: 0.2183, VAL Loss: 0.3055
# $$训练集准确率 accuracy: 0.9135431210396305 $$训练集精确率 precision: 0.9136080622063016 $$训练集召回率 recall: 0.9138149584777044 $$训练集 F1 评分 f1_score: 0.9135360838246134
# @@测试集准确率 accuracy: 0.8778979907264297 @@测试集精确率 precision: 0.8838117184917256 @@测试集召回率 recall: 0.8772314602446483 @@测试集 F1 评分 f1_score: 0.8772776493242384
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [95/100], Train Loss: 0.2200, VAL Loss: 0.2844
# $$训练集准确率 accuracy: 0.9165503168295565 $$训练集精确率 precision: 0.917693497863646 $$训练集召回率 recall: 0.9159928628202552 $$训练集 F1 评分 f1_score: 0.9163785457818939
# @@测试集准确率 accuracy: 0.8856259659969088 @@测试集精确率 precision: 0.8872766570605187 @@测试集召回率 recall: 0.8852780963302753 @@测试集 F1 评分 f1_score: 0.8854264382119268
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [96/100], Train Loss: 0.2184, VAL Loss: 0.2692
# $$训练集准确率 accuracy: 0.9165503168295565 $$训练集精确率 precision: 0.9177526960891351 $$训练集召回率 recall: 0.9159781137197656 $$训练集 F1 评分 f1_score: 0.9163736161571143
# @@测试集准确率 accuracy: 0.9010819165378671 @@测试集精确率 precision: 0.9014230945734063 @@测试集召回率 recall: 0.9012543004587157 @@测试集 F1 评分 f1_score: 0.9010781355636621
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [97/100], Train Loss: 0.2164, VAL Loss: 0.2958
# $$训练集准确率 accuracy: 0.917839115025239 $$训练集精确率 precision: 0.9179606990389577 $$训练集召回率 recall: 0.9176510633339763 $$训练集 F1 评分 f1_score: 0.9177689402481071
# @@测试集准确率 accuracy: 0.8802163833075735 @@测试集精确率 precision: 0.8854403955275115 @@测试集召回率 recall: 0.8795919342507645 @@测试集 F1 评分 f1_score: 0.8796724633699029
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [98/100], Train Loss: 0.2177, VAL Loss: 0.2724
# $$训练集准确率 accuracy: 0.9195575126194824 $$训练集精确率 precision: 0.9195046755460035 $$训练集召回率 recall: 0.9195326007746717 $$训练集 F1 评分 f1_score: 0.9195181177276515
# @@测试集准确率 accuracy: 0.9041731066460588 @@测试集精确率 precision: 0.9042276073033171 @@测试集召回率 recall: 0.9041117163608563 @@测试集 F1 评分 f1_score: 0.9041502094339668
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [99/100], Train Loss: 0.2139, VAL Loss: 0.2694
# $$训练集准确率 accuracy: 0.917839115025239 $$训练集精确率 precision: 0.9188003906170378 $$训练集召回率 recall: 0.9173314994900366 $$训练集 F1 评分 f1_score: 0.9176856763405391
# @@测试集准确率 accuracy: 0.901854714064915 @@测试集精确率 precision: 0.9018418317984735 @@测试集召回率 recall: 0.9018850344036697 @@测试集 F1 评分 f1_score: 0.9018499661063515
# label_train shape: torch.Size([9311])
# train_pred shape: (9311, 1, 1, 1)
# Epoch [100/100], Train Loss: 0.2112, VAL Loss: 0.3434
# $$训练集准确率 accuracy: 0.9155837181827945 $$训练集精确率 precision: 0.9180444028409376 $$训练集召回率 recall: 0.9147528997100867 $$训练集 F1 评分 f1_score: 0.915306185933231
# @@测试集准确率 accuracy: 0.8639876352395672 @@测试集精确率 precision: 0.8812082210914896 @@测试集召回率 recall: 0.8651423929663609 @@测试集 F1 评分 f1_score: 0.8626857032606599
# fold号: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      21 # 构建训练集、验证集、测试集
#      22 epoch_train = data_all[train_ind[A[:int(0.8 * n)]]]
# ---> 23 epoch_val = data_all[train_ind[A[int(0.8 * n):]]]
#      24 epoch_test = data_all[test_ind]
#      25 label_train = label_all[train_ind[A[:int(0.8 * n)]]]
#
# KeyboardInterrupt:

# %%
# 假设 accuracy 列表包含了 1000 个准确率值
# 每一折包含 100 个 epoch
num_folds = 10
epochs_per_fold = 100

# 打印每一折的最大准确率和对应的epoch
for fold in range(num_folds):
    # 获取当前折的准确率列表
    start_idx = fold * epochs_per_fold
    end_idx = (fold + 1) * epochs_per_fold
    fold_accuracy = accuracy[start_idx:end_idx]

    # 找到最大准确率和对应的epoch
    max_acc = max(fold_accuracy)
    max_epoch = fold_accuracy.index(max_acc) + 1  # +1 因为索引从0开始

    # 打印结果
    print(f'第{fold + 1}折准确率最高为{max_acc:.4f}，对应的epoch为{max_epoch}')
