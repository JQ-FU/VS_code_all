# %%
#导入数据时增加一个维度变为（10505，1，30，200），都要增加吗？
#batchsize=16的时候，是怎么放入模型的？第一个卷积输入通道为1，是（1500，1，30，1024）中的1吗？
#（1500，1，30，1024）叫3维数据还是4？不是二维卷积码？
#（8，1，1，64）解释？
#实例化类的时候，传入的参数是——init的？
#标签制作：不用独热编码的区别？
#打印的print("block1", x.shape)指的是这一层的数据的形状吗
#十折交叉验证修改一下？不知道对不对 chatgpt生成的
#classes_num=2去除的时候，EEGNet.__init__() missing 1 required positional argument: 'classes_num'

# %%
import random
import torch
from sklearn.model_selection import KFold
import math
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
import numpy as np
import torch.nn as nn
import torch.nn.functional as F

# %%
# 设置GPU使用方式
# 获取GPU列表
gpus = [torch.cuda.device(i) for i in range(torch.cuda.device_count())]

if gpus:
    try:
        # 设置每个GPU为增长式占用
        for gpu in gpus:
            torch.cuda.set_per_process_memory_fraction(1.0, gpu)  # 可根据需要调整占用比例
    except RuntimeError as e:
        # 打印异常
        print(e)

# %%
class SCNNB(nn.Module):
    def __init__(self):
        super(SCNNB, self).__init__()

        self.conv1 = nn.Conv2d(1,32,kernel_size=(3,3))
        self.BN1 = nn.BatchNorm2d(32,False)
        self.pooling1 = nn.MaxPool2d(2,2)

        self.conv2 = nn.Conv2d(32,64,kernel_size=(3,3))
        self.BN2 = nn.BatchNorm2d(64,False)
        self.pooling2 = nn.MaxPool2d(2,2)

        self.fc1 = nn.Linear(1600,1280)
        self.fc2 = nn.Linear(1280,10)
        
    def forward(self,x):
        #print('第零层',x.shape)
        x = self.pooling1(F.relu(self.BN1(self.conv1(x))))
        #print('第一层',x.shape)
        x = self.pooling2(F.relu(self.BN2(self.conv2(x))))
        #print('第二层',x.shape)
        x = x.reshape(-1,1600)
        #print('第三层',x.shape)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, 0.5)
        x = self.fc2(x)  
        #print(x.shape)
        return x

# %%
import torch
from torchvision import datasets, transforms

# 假设数据集的路径
data_path = 'D:\code\classifier_data'

# 定义数据转换
transform = transforms.Compose([
    transforms.ToTensor(),  # 将图片转换为 Tensor
    transforms.Normalize((0,), (255,))  # 归一化
])

# 加载 MNIST 数据集
mnist_dataset = datasets.MNIST(root=data_path, train=True, transform=transform, download=False)

# 将数据和标签分离
data = mnist_dataset.data
labels = mnist_dataset.targets

# 将数据和标签转换为 Tensor
data_all = data.unsqueeze(1)  # 添加通道维度 (N, C, H, W)，其中 C = 1
label_all = labels.long()  # 确保标签为 long 类型

# %%
# 创建十折交叉验证
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# 保存结果的列表
historys = []
test_pred = []
test_real = []
accuracy, precision, recall, f1score = [], [], [], []
batchsz = 16
num_epochs = 100
# 进行十折交叉验证
for fold, (train_ind, test_ind) in enumerate(kfold.split(data_all, label_all)):
    print('fold号:', fold + 1)

    # 每一折验证前都要打乱训练集样本顺序
    n = len(train_ind)
    A = np.linspace(0, n - 1, n, dtype=int)
    random.shuffle(A)

    # 构建训练集、验证集、测试集
    epoch_train = data_all[train_ind[A[:int(0.8 * n)]]]
    epoch_val = data_all[train_ind[A[int(0.8 * n):]]]
    epoch_test = data_all[test_ind]
    label_train = label_all[train_ind[A[:int(0.8 * n)]]]
    label_val = label_all[train_ind[A[int(0.8 * n):]]]
    label_test = label_all[test_ind]

    # 转换为Tensor并创建DataLoader
    train_dataset = TensorDataset(torch.tensor(epoch_train, dtype=torch.float32), torch.tensor(label_train, dtype=torch.long))
    val_dataset = TensorDataset(torch.tensor(epoch_val, dtype=torch.float32), torch.tensor(label_val, dtype=torch.long))
    
    train_loader = DataLoader(train_dataset, batch_size=batchsz, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batchsz, shuffle=False)

    # 选择、创建模型
    model = SCNNB()
    #print(model)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    # 配置模型训练
    criterion = nn.CrossEntropyLoss()  # 使用交叉熵损失
    
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    

    # 开始训练模型
    print('开始训练!!')
    history = {'train_loss': [], 'val_loss': []}

    for epoch in range(num_epochs):  # 训练100个epoch
        model.train()
        running_loss = 0.0

        # 训练阶段
        for inputs, targets in train_loader:
            #print(f"训练批次输入数据形状: {inputs.shape}")
            inputs = inputs.to(device)
            
            targets = targets.to(device)
            optimizer.zero_grad()
            
            outputs = model(inputs)
            #print(outputs.shape)
            targets = targets.view(-1) 
            #targets=targets.view(-1,1).float()
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)
        history['train_loss'].append(avg_train_loss)

        print('Epoch:{}/{}'.format(epoch+1,num_epochs))
        # 计算训练集的指标
        with torch.no_grad():
            #train_pred = model(torch.tensor(epoch_train, dtype=torch.float32).to(device))
            epoch_train = epoch_train.to(torch.float32)
            train_pred = model(epoch_train.clone().detach().to(device))
            train_pred = torch.argmax(train_pred, dim=1).cpu().numpy()
            
            acc_train = accuracy_score(label_train, train_pred)
            pre_train = precision_score(label_train, train_pred, average='macro')
            rec_train = recall_score(label_train, train_pred, average='macro')
            f1_train = f1_score(label_train, train_pred, average='macro')

        # 输出训练集指标
        print(f"$$训练集准确率 accuracy: {acc_train}",f"$$训练集精确率 precision: {pre_train}",f"$$训练集召回率 recall: {rec_train}",f"$$训练集 F1 评分 f1_score: {f1_train}")
        

        # 验证阶段
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, targets in val_loader:
                

                inputs = inputs.to(device)
            
                targets = targets.to(device)
                outputs = model(inputs)
                #targets=targets.view(-1,1).float()
                targets = targets.view(-1)
                loss = criterion(outputs, targets)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        
        history['val_loss'].append(avg_val_loss)

        # 保存训练记录
        historys.append(history)

        # 计算、保存测试结果
        model.eval()
        with torch.no_grad():
            #pred_test = model(torch.tensor(epoch_test, dtype=torch.float32).to(device))
            epoch_test = epoch_test.to(torch.float32)
            pred_test = model(epoch_test.clone().detach().to(device))
            pred_test = torch.argmax(pred_test, dim=1).cpu().numpy()  # 修改：使用sigmoid函数并阈值化

        # 保存预测结果和真实结果
        test_pred.append(pred_test)
        test_real.append(label_test)

        # 计算准确率，精确率，召回率，F1评分
        acc = accuracy_score(label_test, pred_test)
        pre = precision_score(label_test, pred_test, average='macro')
        rec = recall_score(label_test, pred_test, average='macro')
        f1 = f1_score(label_test, pred_test, average='macro')
        
        accuracy.append(acc)
        precision.append(pre)
        recall.append(rec)
        f1score.append(f1)
        
        print(f"$$测试集准确率 accuracy: {acc}",f"$$测试集精确率 precision: {pre}",f"$$测试集召回率 recall: {rec}",f"$$测试集 F1 评分 f1_score: {f1}")
        

# 将每一折 history 中误差结果保存（训练集和测试集，用于反映训练过程）    
loss_train = []
loss_val = []
for history_s in historys:
    loss_val.append(history_s['val_loss'])
    loss_train.append(history_s['train_loss'])
# Out:
# fold号: 1
# 开始训练!!
# C:\Users\FJQ\AppData\Local\Temp\ipykernel_11472\3428888435.py:29: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_dataset = TensorDataset(torch.tensor(epoch_train, dtype=torch.float32), torch.tensor(label_train, dtype=torch.long))
# C:\Users\FJQ\AppData\Local\Temp\ipykernel_11472\3428888435.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   val_dataset = TensorDataset(torch.tensor(epoch_val, dtype=torch.float32), torch.tensor(label_val, dtype=torch.long))
# Epoch:1/100
# $$训练集准确率 accuracy: 0.974837962962963 $$训练集精确率 precision: 0.9748101203423809 $$训练集召回率 recall: 0.974933061190459 $$训练集 F1 评分 f1_score: 0.9746417868952172
# $$测试集准确率 accuracy: 0.9718333333333333 $$测试集精确率 precision: 0.972336061921285 $$测试集召回率 recall: 0.9719496723429314 $$测试集 F1 评分 f1_score: 0.9718244752394478
# Epoch:2/100
# $$训练集准确率 accuracy: 0.9852546296296296 $$训练集精确率 precision: 0.9853154469661588 $$训练集召回率 recall: 0.9851329070156373 $$训练集 F1 评分 f1_score: 0.9851785519363017
# $$测试集准确率 accuracy: 0.98 $$测试集精确率 precision: 0.9800115661735036 $$测试集召回率 recall: 0.9799399650511094 $$测试集 F1 评分 f1_score: 0.9799091583786497
# Epoch:3/100
# $$训练集准确率 accuracy: 0.9864583333333333 $$训练集精确率 precision: 0.9866947710582051 $$训练集召回率 recall: 0.9863315171558643 $$训练集 F1 评分 f1_score: 0.9864349600729886
# $$测试集准确率 accuracy: 0.9828333333333333 $$测试集精确率 precision: 0.9830730162996263 $$测试集召回率 recall: 0.9825836644267095 $$测试集 F1 评分 f1_score: 0.982746044264028
# Epoch:4/100
# $$训练集准确率 accuracy: 0.987199074074074 $$训练集精确率 precision: 0.987269038839211 $$训练集召回率 recall: 0.9871530193862794 $$训练集 F1 评分 f1_score: 0.9871256210135961
# $$测试集准确率 accuracy: 0.9816666666666667 $$测试集精确率 precision: 0.9820713715973097 $$测试集召回率 recall: 0.9816264918499321 $$测试集 F1 评分 f1_score: 0.9817277796302845
# Epoch:5/100
# $$训练集准确率 accuracy: 0.992037037037037 $$训练集精确率 precision: 0.9920658053248703 $$训练集召回率 recall: 0.9919938380148101 $$训练集 F1 评分 f1_score: 0.9920112447876972
# $$测试集准确率 accuracy: 0.9861666666666666 $$测试集精确率 precision: 0.9861386580112891 $$测试集召回率 recall: 0.9862588049141008 $$测试集 F1 评分 f1_score: 0.9861559362076656
# Epoch:6/100
# $$训练集准确率 accuracy: 0.9908564814814815 $$训练集精确率 precision: 0.9909768352299766 $$训练集召回率 recall: 0.990789653103214 $$训练集 F1 评分 f1_score: 0.9908241326668484
# $$测试集准确率 accuracy: 0.9845 $$测试集精确率 precision: 0.9846310718689045 $$测试集召回率 recall: 0.9842576751045152 $$测试集 F1 评分 f1_score: 0.9843433448617324
# Epoch:7/100
# $$训练集准确率 accuracy: 0.9953935185185185 $$训练集精确率 precision: 0.9953719320518675 $$训练集召回率 recall: 0.9954012513391298 $$训练集 F1 评分 f1_score: 0.9953843591846189
# $$测试集准确率 accuracy: 0.9866666666666667 $$测试集精确率 precision: 0.9865346357556593 $$测试集召回率 recall: 0.9867436502169559 $$测试集 F1 评分 f1_score: 0.9866109127641997
# Epoch:8/100
# $$训练集准确率 accuracy: 0.9939583333333334 $$训练集精确率 precision: 0.993899683318784 $$训练集召回率 recall: 0.9939853987988971 $$训练集 F1 评分 f1_score: 0.9939320854863818
# $$测试集准确率 accuracy: 0.986 $$测试集精确率 precision: 0.9859698737482676 $$测试集召回率 recall: 0.9860267852136259 $$测试集 F1 评分 f1_score: 0.9859622924923658
# Epoch:9/100
# $$训练集准确率 accuracy: 0.9941666666666666 $$训练集精确率 precision: 0.9941789583057548 $$训练集召回率 recall: 0.9941022133382246 $$训练集 F1 评分 f1_score: 0.9941260245889009
# $$测试集准确率 accuracy: 0.9863333333333333 $$测试集精确率 precision: 0.986378248687618 $$测试集召回率 recall: 0.9863054382296556 $$测试集 F1 评分 f1_score: 0.9862901876372948
# Epoch:10/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 80
#      77 with torch.no_grad():
#      78     #train_pred = model(torch.tensor(epoch_train, dtype=torch.float32).to(device))
#      79     epoch_train = epoch_train.to(torch.float32)
# ---> 80     train_pred = model(epoch_train.clone().detach().to(device))
#      82     train_pred = torch.argmax(train_pred, dim=1).cpu().numpy()
#      84     acc_train = accuracy_score(label_train, train_pred)
#
# KeyboardInterrupt:
